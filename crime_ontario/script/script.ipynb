# %%
import pandas as pd

# %%
df = pd.read_csv('../data/1314-010_violent_crime_severity_index_csv_2008-12.csv', encoding='cp1252')

# %%
df.head()
# Out:
#                                           Unnamed: 0  \
# 0  Geography (Footnotes in parentheses–see bottom...
# 1                                        Canada (34)
# 2                          Newfoundland and Labrador
# 3                               Prince Edward Island
# 4                                        Nova Scotia
#
#   Violent Crime Severity Index – Baseline 2006 = 100  Unnamed: 2  Unnamed: 3  \
# 0                                               2008     2009.00     2010.00
# 1                                              94.88       94.04       88.91
# 2                                              67.17       61.79       70.63
# 3                                              43.82       44.42       41.49
# 4                                              88.63       89.56       84.33
#
#    Unnamed: 4  Unnamed: 5
# 0     2011.00     2012.00
# 1       85.38       81.42
# 2       62.12       65.94
# 3       44.20       45.05
# 4       86.90       78.04

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Violent Crime Severity Index – Baseline 2006 = 100',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0   Geography (Footnotes in parentheses–see bottom...
# 1                                         Canada (34)
# 2                           Newfoundland and Labrador
# 3                                Prince Edward Island
# 4                                         Nova Scotia
# 5                                       New Brunswick
# 6                                         Quebec (34)
# 7                                         Ontario (7)
# 8                 Ottawa-Gatineau, Ontario/Quebec (6)
# 9                   Ottawa-Gatineau, Ontario part (6)
# 10                              Kingston, Ontario (8)
# 11                          Peterborough, Ontario (8)
# 12                              Toronto, Ontario (25)
# 13                             Hamilton, Ontario (25)
# 14                     St.Catharines-Niagara, Ontario
# 15              Kitchener-Cambridge-Waterloo, Ontario
# ...

# %%
# delete everyhting from 30 onwards
df.drop(df.index[30:], axis=0, inplace=True)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0   Geography (Footnotes in parentheses–see bottom...
# 1                                         Canada (34)
# 2                           Newfoundland and Labrador
# 3                                Prince Edward Island
# 4                                         Nova Scotia
# 5                                       New Brunswick
# 6                                         Quebec (34)
# 7                                         Ontario (7)
# 8                 Ottawa-Gatineau, Ontario/Quebec (6)
# 9                   Ottawa-Gatineau, Ontario part (6)
# 10                              Kingston, Ontario (8)
# 11                          Peterborough, Ontario (8)
# 12                              Toronto, Ontario (25)
# 13                             Hamilton, Ontario (25)
# 14                     St.Catharines-Niagara, Ontario
# 15              Kitchener-Cambridge-Waterloo, Ontario
# ...

# %%
# rename the first column
df.rename(columns={'Unnamed: 0': 'Location'}, inplace=True)

# %%
df
# Out:
#                                              Location  \
# 0   Geography (Footnotes in parentheses–see bottom...
# 1                                         Canada (34)
# 2                           Newfoundland and Labrador
# 3                                Prince Edward Island
# 4                                         Nova Scotia
# 5                                       New Brunswick
# 6                                         Quebec (34)
# 7                                         Ontario (7)
# 8                 Ottawa-Gatineau, Ontario/Quebec (6)
# 9                   Ottawa-Gatineau, Ontario part (6)
# 10                              Kingston, Ontario (8)
# 11                          Peterborough, Ontario (8)
# 12                              Toronto, Ontario (25)
# 13                             Hamilton, Ontario (25)
# 14                     St.Catharines-Niagara, Ontario
# 15              Kitchener-Cambridge-Waterloo, Ontario
# ...

# %%
df.Location.unique()
# Out:
# array(['Geography (Footnotes in parentheses–see bottom of spreadsheet)',
#        'Canada (34)', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec (34)', 'Ontario (7)',
#        'Ottawa-Gatineau, Ontario/Quebec (6)',
#        'Ottawa-Gatineau, Ontario part (6)', 'Kingston, Ontario (8)',
#        'Peterborough, Ontario (8)', 'Toronto, Ontario (25)',
#        'Hamilton, Ontario (25)', 'St.Catharines-Niagara, Ontario',
#        'Kitchener-Cambridge-Waterloo, Ontario', 'Brantford, Ontario (8)',
#        'Guelph, Ontario (8)', 'London, Ontario', 'Windsor, Ontario',
#        'Barrie, Ontario (8)', 'Sudbury, Ontario', 'Thunder Bay, Ontario',
#        'Manitoba', 'Saskatchewan (11)', 'Alberta',
#        'British Columbia (32)', 'Yukon', 'Northwest Territories (15)',
#        'Nunavut (15)'], dtype=object)

# %%
df.Location[7]
# Out:
# 'Ontario (7)'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.Location[0:7])
