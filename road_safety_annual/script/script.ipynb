# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_chapter1_table1 = pd.read_csv('../data//ORSAR2016-Open Data/Chapter 1/Table 1.1.csv')

# %%
df_chapter1_table1.head(10)
# Out:
#   Table 1.1: Selected Diagnoses of Motor Vehicle Collision Injuries Hospitalized in Ontario, 2016 / 2017 Fiscal Year  \
# 0                                 Selected Diagnoses
# 1                                                NaN
# 2                                   Fracture of head
# 3                         Fracture of neck and trunk
# 4                             Fracture of upper limb
# 5                             Fracture of lower limb
# 6          Fractures involving multiple body regions
# 7                   Dislocation, sprains and strains
# 8  Dislocations, sprains, and strains involving m...
# 9                                Intracranial injury
#
#             Unnamed: 1             Unnamed: 2
# 0  Hospital Admissions  Hospital Days of Stay
# 1                  NaN                    NaN
# 2                  126                    719
# 3                  998                  8,794
# 4                  428                  2,197
# ...

# %%
df_chapter1_table2 = pd.read_csv('../data//ORSAR2016-Open Data/Chapter 1/Table 1.2.csv')

# %%
df_chapter1_table2.head(10)
# Out:
#                                            Table 1.2           Unnamed: 1  \
# 0  Selected Surgical Procedures for Motor Vehicle...                  NaN
# 1                                 Selected Procedure  Hospital Admissions
# 2                                                NaN                  NaN
# 3                 Head, brain, and cerebral meninges                   97
# 4            Spinal cord, spinal canal, and meninges                   13
# 5                           Nose, mouth, and pharynx                   18
# 6     Chest wall, pleura, mediastinum, and diaphragm                    0
# 7                             Bone marrow and spleen                  150
# 8                                             Kidney                    0
# 9                            Facial bones and joints                   62
#
#               Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0                    NaN         NaN         NaN         NaN         NaN
# ...

# %%
df_chapter1_table2.columns
# Out:
# Index(['Table 1.2', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df_chapter1_table2.isnull().sum()
# Out:
# Table 1.2      5
# Unnamed: 1     9
# Unnamed: 2     9
# Unnamed: 3    22
# Unnamed: 4    22
# Unnamed: 5    22
# Unnamed: 6    22
# dtype: int64

# %%
df_synopsis = pd.read_csv('../data/ORSAR2016-Open Data/Chapter 1/1A Synopsis.csv')

# %%
df_synopsis.head(10)
# Out:
#                                         1a. Synopsis Unnamed: 1  Unnamed: 2  \
# 0                          Selected Statistics: 2016        NaN         NaN
# 1                        Total Reportable Collisions    208,404         NaN
# 2               Total Drivers Involved in Collisions    378,490         NaN
# 3              Total Vehicles Involved in Collisions    391,544         NaN
# 4                                   Fatal Collisions        527         NaN
# 5                         Personal Injury Collisions     39,685         NaN
# 6                         Property Damage Collisions    168,192         NaN
# 7                                     Persons Killed        579         NaN
# 8  Drivers Killed (excludes All Terrain Vehicle a...        333         NaN
# 9     Drivers Killed (Impaired or Had Been Drinking)         88         NaN
#
#    Unnamed: 3  Unnamed: 4
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# ...

# %%
df_synopsis.columns
# Out:
# Index(['1a. Synopsis', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df_synopsis.isnull().sum()
# Out:
# 1a. Synopsis     0
# Unnamed: 1       1
# Unnamed: 2      23
# Unnamed: 3      23
# Unnamed: 4      23
# dtype: int64

# %%
df_synopsis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   1a. Synopsis  23 non-null     object
#  1   Unnamed: 1    22 non-null     object
#  2   Unnamed: 2    0 non-null      float64
#  3   Unnamed: 3    0 non-null      float64
#  4   Unnamed: 4    0 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 1.0+ KB

# %%
df_chapter1_table1.head(20)
# Out:
#    Table 1.1: Selected Diagnoses of Motor Vehicle Collision Injuries Hospitalized in Ontario, 2016 / 2017 Fiscal Year  \
# 0                                  Selected Diagnoses
# 1                                                 NaN
# 2                                    Fracture of head
# 3                          Fracture of neck and trunk
# 4                              Fracture of upper limb
# 5                              Fracture of lower limb
# 6           Fractures involving multiple body regions
# 7                    Dislocation, sprains and strains
# 8   Dislocations, sprains, and strains involving m...
# 9                                 Intracranial injury
# 10      Internal injury of chest, abdomen, and pelvis
# 11                 Open wound of head, neck, or trunk
# 12                           Open wound of upper limb
# 13                           Open wound of lower limb
# 14        Open wounds involving multiple body regions
# ...

# %%
df_chapter1_table1['Table 1.1: Selected Diagnoses of Motor Vehicle Collision Injuries Hospitalized in Ontario, 2016 / 2017 Fiscal Year']
# Out:
# 0                                    Selected Diagnoses
# 1                                                   NaN
# 2                                      Fracture of head
# 3                            Fracture of neck and trunk
# 4                                Fracture of upper limb
# 5                                Fracture of lower limb
# 6             Fractures involving multiple body regions
# 7                      Dislocation, sprains and strains
# 8     Dislocations, sprains, and strains involving m...
# 9                                   Intracranial injury
# 10        Internal injury of chest, abdomen, and pelvis
# 11                   Open wound of head, neck, or trunk
# 12                             Open wound of upper limb
# 13                             Open wound of lower limb
# 14          Open wounds involving multiple body regions
# 15                                      Other diagnosis
# 16                           Total Admissions and Days
# ...

# %%
df_chapter1_table1['Table 1.1: Selected Diagnoses of Motor Vehicle Collision Injuries Hospitalized in Ontario, 2016 / 2017 Fiscal Year'].value_counts(ascending=False)
# Out:
# Open wound of head, neck, or trunk                                                                                    1
# Dislocation, sprains and strains                                                                                      1
# Open wound of lower limb                                                                                              1
# Fracture of upper limb                                                                                                1
# Intracranial injury                                                                                                   1
# Total Admissions and Days                                                                                             1
# Fracture of head                                                                                                      1
# Source: Ministry of Health and Long-Term Care, Health Solutions Delivery Branch, Health Data Decision Support Unit    1
# ...

# %%
df_chapter3_table3_1 = pd.read_csv('../data//ORSAR2016-Open Data/Chapter 3/Table 3.1.csv')

# %%
df_chapter3_table3_1.head(10)
# Out:
#                   3A.  TYPES OF COLLISIONS          Unnamed: 1  \
# 0  Table 3.1: Class of Collision 1988-2016                 NaN
# 1                                     Year  Class of Collision
# 2                                      NaN               Fatal
# 3                                     1988               1,076
# 4                                     1989               1,106
# 5                                     1990                 959
# 6                                     1991                 956
# 7                                     1992                 942
# 8                                     1993                 987
# 9                                     1994                 875
#
#         Unnamed: 2       Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0              NaN              NaN        NaN         NaN         NaN
# 1              NaN              NaN      Total         NaN         NaN
# ...

# %%
df_chapter3_table3_1['3A.  TYPES OF COLLISIONS']
# Out:
# 0     Table 3.1: Class of Collision 1988-2016
# 1                                        Year
# 2                                         NaN
# 3                                        1988
# 4                                        1989
# 5                                        1990
# 6                                        1991
# 7                                        1992
# 8                                        1993
# 9                                        1994
# 10                                       1995
# 11                                       1996
# 12                                       1997
# 13                                       1998
# 14                                       1999
# 15                                       2000
# 16                                       2001
# 17                                       2002
# 18                                       2003
# 19                                       2004
# ...

# %%
df_chapter4 = pd.read_csv('../data//ORSAR2016-Open Data/Chapter 4/Chapter 4.csv')

# %%
df_chapter4.head(10)
# Out:
#   Unnamed: 0  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
#
#   Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016  \
# 0                                 Place of Collision
# 1                                                NaN
# 2                                      ONTARIO TOTAL
# 3                                             Algoma
# 4                                      Blind River T
# 5                                      Elliot Lake C
# 6                                     Huron Shores M
# 7             Macdonald, Meredith & Aberdeen Addl TP
# 8                                 Sault Ste. Marie C
# 9                                 Provincial Highway
#
#          Unnamed: 2          Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0  Total Collisions  Class of Collision              NaN              NaN
# ...

# %%
df_chapter4.columns
# Out:
# Index(['Unnamed: 0',
#        'Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
df_chapter4.isnull().sum()
# Out:
# Unnamed: 0                                                                                                           499
# Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016      6
# Unnamed: 2                                                                                                            63
# Unnamed: 3                                                                                                            62
# Unnamed: 4                                                                                                            63
# Unnamed: 5                                                                                                            63
# Unnamed: 6                                                                                                            62
# Unnamed: 7                                                                                                            63
# ...

# %%
df_chapter4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   Unnamed: 0                                                                                                         1 non-null      object
#  1   Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016  494 non-null    object
#  2   Unnamed: 2                                                                                                         437 non-null    object
#  3   Unnamed: 3                                                                                                         438 non-null    object
# ...

# %%
df_chapter4.head()
# Out:
#   Unnamed: 0  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#   Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016  \
# 0                                 Place of Collision
# 1                                                NaN
# 2                                      ONTARIO TOTAL
# 3                                             Algoma
# 4                                      Blind River T
#
#          Unnamed: 2          Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0  Total Collisions  Class of Collision              NaN              NaN
# 1               NaN               Fatal  Personal Injury  Property Damage
# 2           208,389                 527           39,684          168,178
# 3               NaN                 NaN              NaN              NaN
# 4                17                   0                2               15
#
# ...

# %%
df_chapter4['Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016'][0:10]
# Out:
# 0                        Place of Collision
# 1                                       NaN
# 2                             ONTARIO TOTAL
# 3                                    Algoma
# 4                             Blind River T
# 5                             Elliot Lake C
# 6                            Huron Shores M
# 7    Macdonald, Meredith & Aberdeen Addl TP
# 8                        Sault Ste. Marie C
# 9                        Provincial Highway
# Name: Table 4.1: Place of Collision - Class of Collision, Persons Killed, Injured and Motor Vehicle Registrations, 2016, dtype: object
